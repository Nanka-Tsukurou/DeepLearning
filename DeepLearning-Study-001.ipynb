# %% [markdown]
# # ゼロから作る Deep Learning 読書会(1)

# %% [markdown]
# ## 第1章 Python入門

# %% [markdown]
# # 1.1 Pythonとは

# %% [markdown]
# # 1.2 Pythonのインストール

# %% [markdown]
# ## 1.2.1 Pythonのバージョン
#
# - Python2系と3系がある。
# - Python3を使用する。

# %% [markdown]
# ## 1.2.2 使用する外部ライブラリ
#
# - NumPy
# - Matplotlib

# %% [markdown]
# ## 1.2.3 Anacondaディストリビューション

# %% [markdown]
# # 1.3 Pythonインタプリタ

# %% [markdown]
# ### 1.3.1 算術計算

# %% [markdown]
# 四則演算

# %%
1+2
# Out:
# 3

# %%
1-2
# Out:
# -1

# %%
4+5
# Out:
# 9

# %%
4*5
# Out:
# 20

# %%
7/5
# Out:
# 1.4

# %% [markdown]
# 累乗

# %%
3**2
# Out:
# 9

# %% [markdown]
# ## 1.3.2 データ型

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
int(10.0)
# Out:
# 10

# %%
type(int(10.0))
# Out:
# int

# %% [markdown]
# ## 1.3.3 変数

# %%
x = 10
print(x)
# Out:
# 10

# %%
y=3.14
print(y)
# Out:
# 3.14

# %%
type(x+y)
# Out:
# float

# %% [markdown]
# ## 1.3.4 リスト

# %% [markdown]
# リストの中身を作成する

# %%
a = [1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 長さを取ってみる

# %%
len(a)
# Out:
# 5

# %% [markdown]
# 要素にアクセスする

# %%
a[0]
# Out:
# 1

# %%
a[4]
# Out:
# 5

# %% [markdown]
# 値を代入してみる

# %%
a[4]=99
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %% [markdown]
# コロン(:)を利用してアクセスする

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 99]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1]
# Out:
# [1, 2, 3, 4]

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %% [markdown]
# リストは、[] だが、() や、{} は、どういった変数タイプか

# %%
a = ( 1,2,3,4,5 )
print(a)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(a)
# Out:
# tuple

# %%
b = [1,2,3,4,5]
type(b)
# Out:
# list

# %%
c = { 1,2,3,4,5 }
type(c)
# Out:
# set

# %% [markdown]
# ## 1.3.5 ディクショナリ

# %%
me = {'height':180 }
me['height']
# Out:
# 180

# %%
me['weight'] = 70

# %%
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %%
hungry = True

# %%
type(hungry)
# Out:
# bool

# %%
sleep = False

# %%
print(sleep)
# Out:
# False

# %%
hungry and sleep
# Out:
# False

# %%
hungry or sleep
# Out:
# True

# %% [markdown]
# ## 1.3.7 if文

# %%
if hungry:
    print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False

if hungry:
    print("I'm hungry")
else:
    print("I'm not hungry")
# Out:
# I'm not hungry

# %% [markdown]
# ## 1.3.8 for文

# %%
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# シングルクォートとダブルクォートの関係

# %%
print("a'bc")
# Out:
# a'bc

# %% [markdown]
# ## 1.3.9 関数

# %%
def hello():
    print("Hello World!")

hello()
# Out:
# Hello World!

# %%
y = 1
if y==9:
    print(y)
elif y==10:
    print("not")
else:
    print("abc")
# Out:
# abc

# %%
def hello(object):
    print("Hello " + object + "!")

hello("Tanaka")
# Out:
# Hello Tanaka!

# %% [markdown]
# ## 1.4.2 クラス

# %%
class Man:
    def __init__(self, name):
        self.name = name
        print("Initalized!")

    def hello(self):
        print("Hello " + self.name + "!")

    def goodbye(self):
        print("Good-bye " + self.name + "!")

m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initalized!
# Hello David!
# Good-bye David!

# %% [markdown]
# ## 1.5 NumPy

# %% [markdown]
# ## 1.5.1 NumPy のインポート

# %%
import numpy as np

# %% [markdown]
# ## 1.5.2 NumPy 配列の生成

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
# Out:
# [ 1.  2.  3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 1.5.3 NumPy の算術計算

# %%
x = np.array([1.0,2.0,3.0])
y = np.array([2.0,4.0,6.0])

# %%
x + y
# Out:
# array([ 3.,  6.,  9.])

# %%
x - y
# Out:
# array([-1., -2., -3.])

# %%
x * y
# Out:
# array([  2.,   8.,  18.])

# %%
x / y
# Out:
# array([ 0.5,  0.5,  0.5])

# %%
x / 2.0
# Out:
# array([ 0.5,  1. ,  1.5])

# %% [markdown]
# ## 1.5.4 NumPy の N 次元配列

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int64')

# %%
B = np.array([[3,0],[0,6]])
A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A * B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A * 10
# Out:
# array([[10, 20],
#        [30, 40]])

# %% [markdown]
# ## 1.5.5 ブロードキャスト

# %%
B = np.array([10,20])

# %%
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ## 1.5.6 要素へのアクセス

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten()
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0,2,4])]
# Out:
# array([51, 14,  0])

# %%
X>15
# Out:
# array([ True,  True, False,  True, False, False], dtype=bool)

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# ## 1.6 Matplotlib

# %% [markdown]
# ## 1.6.1 単純なグラフの作画

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0,6,0.1)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## 1.6.2 pyplot の機能

# %%
import numpy as np
import matplotlib.pyplot as plt

# データの作成
x = np.arange(0, 6, 0.1) # 0から6まで0.1刻みで生成
y1 = np.sin(x)
y2 = np.cos(x)

# グラフの描画
plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle = "--", label="cos")
plt.xlabel("x") # x軸のラベル
plt.ylabel("y") # y軸のラベル
plt.title('sin & cos')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## 1.6.3 画像の表示

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread("lena.png")
plt.imshow(img)

plt.show()

# %% [markdown]
# ## 1.7 まとめ
#
# - Python は、オープンソースで自由に使える
# - 「インタプリタ」と「スクリプトファイル」の2つの実行モードがある。
# - 関数やクラスというまとめかたがある。
# - NumPy には、多次元配列を操作するためのメソッドが多数ある。
